# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix
import time

# %%
animes = pd.read_csv('anime.csv')
ratings = pd.read_csv('rating.csv')

# %%
animes = animes[animes['type'] == 'TV']
animes
# Out:
#        anime_id                                               name  \
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# 5         32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# ...         ...                                                ...
# 11104     34522                          Wake Up, Girls! Shin Shou
# 11106     34467                             Yami Shibai 4th Season
# 11107     32615                                        Youjo Senki
# 11110     34284  Yuuki Yuuna wa Yuusha de Aru: Washio Sumi no Shou
# 11111     34445       Yuuki Yuuna wa Yuusha de Aru: Yuusha no Shou
#
#                                                    genre type episodes  \
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...   TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...   TV       51
# 3                                       Sci-Fi, Thriller   TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...   TV       51
# 5                 Comedy, Drama, School, Shounen, Sports   TV       10
# ...                                                  ...  ...      ...
# 11104                                       Drama, Music   TV  Unknown
# 11106                     Dementia, Horror, Supernatural   TV  Unknown
# 11107                                    Magic, Military   TV  Unknown
# 11110               Drama, Fantasy, Magic, Slice of Life   TV        6
# 11111               Drama, Fantasy, Magic, Slice of Life   TV        6
#
#        rating  members
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# 5        9.15    93351
# ...       ...      ...
# 11104     NaN      381
# 11106     NaN     1838
# 11107     NaN     6652
# 11110     NaN     2593
# 11111     NaN     4439
#
# [3787 rows x 7 columns]

# %%
ratings.rating.replace({-1: 0}, inplace = True)
ratings.dropna(axis = 0, inplace=True)

# %%
user_counts = ratings.groupby('user_id').count().sort_values(by='rating', ascending=False)
user_counts
# Out:
#          anime_id  rating
# user_id
# 48766       10227   10227
# 42635        3747    3747
# 53698        2905    2905
# 57620        2702    2702
# 59643        2633    2633
# ...           ...     ...
# 11323           1       1
# 48775           1       1
# 11328           1       1
# 48743           1       1
# 46734           1       1
#
# [73515 rows x 2 columns]

# %%
top_users = list(user_counts.head(10000).index)

len(top_users)
# Out:
# 10000

# %%
ratings = ratings[ratings['user_id'].isin(top_users)]
ratings
# Out:
#          user_id  anime_id  rating
# 302            5         6       8
# 303            5        15       6
# 304            5        17       6
# 305            5        18       6
# 306            5        20       6
# ...          ...       ...     ...
# 7813330    73507      8231       5
# 7813331    73507      8348       5
# 7813332    73507      8440       7
# 7813333    73507      8769       8
# 7813334    73507     10067       5
#
# [3923790 rows x 3 columns]

# %%
def get_title_from_index(anime_id):
    title = animes[animes['name'] == movie_id]
    title = list(title['name'])
    return title[0]

def get_index_from_title(title):
    anime_id = animes[animes['name'] == title]
    anime_id = list(anime_id['anime_id'])
    return anime_id[0]

# %%
ratings_dict =  {'Fullmetal Alchemist: Brotherhood':10,
            'Dragon Ball Z':10,
            'Code Geass: Hangyaku no Lelouch R2':8,
            'Steins;Gate':6,
            'Tengen Toppa Gurren Lagann':8,
             'Hunter x Hunter (2011)':10,
             'Boku no Hero Academia':8,
             'Berserk':9,
             'Death Note':9,
             'Monster':8
                }

user_id = 99999

ids = []

for movie_titles in ratings_dict.keys():
    x = get_index_from_title(movie_titles)
    ids.append(x)
    
id_list = [user_id] * len(ratings_dict)

user_ratings = list(zip(id_list,ids, ratings_dict.values()))

user_ratings = pd.DataFrame(user_ratings, columns=ratings.columns)
user_ratings
# Out:
#    user_id  anime_id  rating
# 0    99999      5114      10
# 1    99999       813      10
# 2    99999      2904       8
# 3    99999      9253       6
# 4    99999      2001       8
# 5    99999     11061      10
# 6    99999     31964       8
# 7    99999        33       9
# 8    99999      1535       9
# 9    99999        19       8

# %%
ratings = pd.concat([ratings, user_ratings])
ratings
# Out:
#      user_id  anime_id  rating
# 302        5         6       8
# 303        5        15       6
# 304        5        17       6
# 305        5        18       6
# 306        5        20       6
# ..       ...       ...     ...
# 5      99999     11061      10
# 6      99999     31964       8
# 7      99999        33       9
# 8      99999      1535       9
# 9      99999        19       8
#
# [3923800 rows x 3 columns]

# %%
combined = pd.merge(animes, ratings, on='anime_id')
combined
# Out:
#          anime_id                              name  \
# 0            5114  Fullmetal Alchemist: Brotherhood
# 1            5114  Fullmetal Alchemist: Brotherhood
# 2            5114  Fullmetal Alchemist: Brotherhood
# 3            5114  Fullmetal Alchemist: Brotherhood
# 4            5114  Fullmetal Alchemist: Brotherhood
# ...           ...                               ...
# 2521262      7808  Zukkoke Knight: Don De La Mancha
# 2521263      7808  Zukkoke Knight: Don De La Mancha
# 2521264      7808  Zukkoke Knight: Don De La Mancha
# 2521265      7808  Zukkoke Knight: Don De La Mancha
# 2521266     13455                  Zumomo to Nupepe
#
#                                                      genre type episodes  \
# 0        Action, Adventure, Drama, Fantasy, Magic, Mili...   TV       64
# 1        Action, Adventure, Drama, Fantasy, Magic, Mili...   TV       64
# 2        Action, Adventure, Drama, Fantasy, Magic, Mili...   TV       64
# 3        Action, Adventure, Drama, Fantasy, Magic, Mili...   TV       64
# 4        Action, Adventure, Drama, Fantasy, Magic, Mili...   TV       64
# ...                                                    ...  ...      ...
# 2521262             Adventure, Comedy, Historical, Romance   TV       23
# 2521263             Adventure, Comedy, Historical, Romance   TV       23
# 2521264             Adventure, Comedy, Historical, Romance   TV       23
# 2521265             Adventure, Comedy, Historical, Romance   TV       23
# 2521266                                             Comedy   TV       32
#
#          rating_x  members  user_id  rating_y
# 0            9.26   793665       17        10
# 1            9.26   793665       38        10
# 2            9.26   793665       43         4
# 3            9.26   793665       46         9
# 4            9.26   793665      129         9
# ...           ...      ...      ...       ...
# 2521262      6.47      172     1822         6
# 2521263      6.47      172    48766         0
# 2521264      6.47      172    49127         6
# 2521265      6.47      172    51693         7
# 2521266      7.00      120    48766         0
#
# [2521267 rows x 9 columns]

# %%
anime_mat = combined.pivot_table(index='user_id',columns='name',values='rating_y').fillna(0)
anime_mat
# Out:
# name     .hack//Roots  .hack//Sign  .hack//Tasogare no Udewa Densetsu  \
# user_id
# 5                 0.0          0.0                                0.0
# 7                 0.0          0.0                                0.0
# 17                0.0          0.0                                0.0
# 38                0.0          0.0                                0.0
# 43                0.0          0.0                                0.0
# ...               ...          ...                                ...
# 73499             0.0          0.0                                0.0
# 73502             0.0          0.0                                0.0
# 73503             0.0          0.0                                0.0
# 73507             0.0          0.0                                0.0
# 99999             0.0          0.0                                0.0
#
# name     0-sen Hayato  009-1  07-Ghost  11eyes  \
# user_id
# 5                 0.0    0.0       0.0     0.0
# 7                 0.0    0.0       0.0     0.0
# 17                0.0    0.0       0.0     0.0
# 38                0.0    0.0       0.0     1.0
# 43                0.0    0.0       0.0     9.0
# ...               ...    ...       ...     ...
# 73499             0.0    0.0       0.0     0.0
# 73502             0.0    0.0       0.0     0.0
# 73503             0.0    0.0       0.0     0.0
# 73507             0.0    0.0       0.0     3.0
# 99999             0.0    0.0       0.0     0.0
#
# name     12-sai.: Chicchana Mune no Tokimeki  \
# user_id
# 5                                        0.0
# 7                                        0.0
# 17                                       0.0
# 38                                       0.0
# 43                                       0.0
# ...                                      ...
# 73499                                    0.0
# 73502                                    0.0
# 73503                                    0.0
# 73507                                    0.0
# 99999                                    0.0
#
# name     12-sai.: Chicchana Mune no Tokimeki 2nd Season  \
# user_id
# 5                                                   0.0
# 7                                                   0.0
# 17                                                  0.0
# 38                                                  0.0
# 43                                                  0.0
# ...                                                 ...
# 73499                                               0.0
# 73502                                               0.0
# 73503                                               0.0
# 73507                                               0.0
# 99999                                               0.0
#
# name     2020 Nyeon Ujuui Wonder Kiddy  ...  Zukkoke Knight: Don De La Mancha  \
# user_id                                 ...
# 5                                  0.0  ...                               0.0
# 7                                  0.0  ...                               0.0
# 17                                 0.0  ...                               0.0
# 38                                 0.0  ...                               0.0
# 43                                 0.0  ...                               0.0
# ...                                ...  ...                               ...
# 73499                              0.0  ...                               0.0
# 73502                              0.0  ...                               0.0
# 73503                              0.0  ...                               0.0
# 73507                              0.0  ...                               0.0
# 99999                              0.0  ...                               0.0
#
# name     Zumomo to Nupepe  ef: A Tale of Melodies.  ef: A Tale of Memories.  \
# user_id
# 5                     0.0                      0.0                      0.0
# 7                     0.0                      0.0                      0.0
# 17                    0.0                      0.0                      8.0
# 38                    0.0                      0.0                      0.0
# 43                    0.0                      0.0                      0.0
# ...                   ...                      ...                      ...
# 73499                 0.0                     10.0                     10.0
# 73502                 0.0                      9.0                     10.0
# 73503                 0.0                      0.0                      0.0
# 73507                 0.0                      0.0                      0.0
# 99999                 0.0                      0.0                      0.0
#
# name     gdgd Fairies  gdgd Fairies 2  iDOLM@STER Xenoglossia  s.CRY.ed  \
# user_id
# 5                 0.0             0.0                     0.0       0.0
# 7                 0.0             0.0                     0.0       0.0
# 17                6.0             6.0                     0.0       0.0
# 38                0.0             0.0                     0.0       0.0
# 43                0.0             0.0                     0.0       8.0
# ...               ...             ...                     ...       ...
# 73499             0.0             0.0                     0.0       0.0
# 73502             0.0             0.0                     0.0       0.0
# 73503             0.0             0.0                     0.0       0.0
# 73507             0.0             0.0                     0.0       0.0
# 99999             0.0             0.0                     0.0       0.0
#
# name     xxxHOLiC  xxxHOLiC Kei
# user_id
# 5             2.0           0.0
# 7             0.0           0.0
# 17            0.0           0.0
# 38            0.0           0.0
# 43            7.0           7.0
# ...           ...           ...
# 73499         0.0           0.0
# 73502        10.0          10.0
# 73503         8.0           8.0
# 73507        10.0           9.0
# 99999         0.0           0.0
#
# [9996 rows x 3399 columns]

# %%
anime_mat_sparse = csr_matrix(anime_mat.values)
anime_mat_sparse
# Out:
# <9996x3399 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2058791 stored elements in Compressed Sparse Row format>

# %%
cosine_sim = cosine_similarity(anime_mat_sparse)

# %%
k = 10

# %%
def user_based_recomm():
    #combined = pd.merge(animes,ratings,on='movieId')

    #moviemat = combined.pivot_table(index='userId',columns='title',values='rating').fillna(0)
    #moviemat_sparse = csr_matrix(moviemat.values)
    #cosine_sim = cosine_similarity(moviemat_sparse)

    k = 10

    #moviemat 
    recommender_df = pd.DataFrame(cosine_sim, 
                                  columns=anime_mat.index,
                                  index=anime_mat.index)


    ## Item Rating Based Cosine Similarity
    cosine_df = pd.DataFrame(recommender_df[user_id].sort_values(ascending=False))
    cosine_df.reset_index(level=0, inplace=True)
    cosine_df.columns = ['user_id','cosine_sim']
    similar_usr = list(cosine_df['user_id'][1:k+1].values)
    similarities = list(cosine_df['cosine_sim'][1:k+1].values)

    sims_dict = dict(zip(similar_usr, similarities))

    similar_usr_df = anime_mat.T[similar_usr].fillna(0)

    for i, j in sims_dict.items():
        similar_usr_df[i] = similar_usr_df[i] * j

    similar_usr_df['mean rating'] = similar_usr_df[list(sims_dict.keys())].mean(numeric_only=True,axis=1)
    similar_usr_df.sort_values('mean rating', ascending=False,inplace = True)

    watched = list(ratings_dict.keys())

    similar_usr_df = similar_usr_df[~similar_usr_df.index.isin(watched)]
    
    titles = similar_usr_df.index
    mean_rating = list(similar_usr_df['mean rating'])
    
    recos = pd.DataFrame(columns=['name','mean rating'])
    recos['name'] = titles
    recos['mean rating'] = mean_rating
    
    recos = pd.merge(animes,recos,on='name')
    
    recos.sort_values(by='mean rating', ascending = False, inplace=True)
    recos.reset_index(drop=True, inplace=True)

    return recos.head(20)

# %%
df = user_based_recomm()

df
# Out:
#     anime_id                                            name  \
# 0          6                                          Trigun
# 1       1575                 Code Geass: Hangyaku no Lelouch
# 2        121                             Fullmetal Alchemist
# 3        392                                 Yuu☆Yuu☆Hakusho
# 4      16498                              Shingeki no Kyojin
# 5        136                                 Hunter x Hunter
# 6        263                                  Hajime no Ippo
# 7        857                                        Air Gear
# 8        245                           Great Teacher Onizuka
# 9        226                                      Elfen Lied
# 10      2025           Darker than Black: Kuro no Keiyakusha
# 11        57                                            Beck
# 12     11843                    Danshi Koukousei no Nichijou
# 13      6114             Rainbow: Nisha Rokubou no Shichinin
# 14      2251                                        Baccano!
# 15       267                                        Gungrave
# 16     13601                                     Psycho-Pass
# 17        45         Rurouni Kenshin: Meiji Kenkaku Romantan
# 18      1482                                      D.Gray-man
# 19       658  Touhai Densetsu Akagi: Yami ni Maiorita Tensai
#
#                                                 genre type episodes  rating  \
# 0                              Action, Comedy, Sci-Fi   TV       26    8.32
# 1   Action, Mecha, Military, School, Sci-Fi, Super...   TV       25    8.83
# 2   Action, Adventure, Comedy, Drama, Fantasy, Mag...   TV       51    8.33
# 3   Action, Comedy, Demons, Fantasy, Martial Arts,...   TV      112    8.47
# 4        Action, Drama, Fantasy, Shounen, Super Power   TV       25    8.54
# 5             Action, Adventure, Shounen, Super Power   TV       62    8.48
# 6                      Comedy, Drama, Shounen, Sports   TV       75    8.83
# 7              Action, Comedy, Ecchi, Shounen, Sports   TV       25    7.69
# 8       Comedy, Drama, School, Shounen, Slice of Life   TV       43    8.77
# 9   Action, Drama, Horror, Psychological, Romance,...   TV       13    7.85
# 10               Action, Mystery, Sci-Fi, Super Power   TV       25    8.25
# 11       Comedy, Drama, Music, Shounen, Slice of Life   TV       26    8.40
# 12             Comedy, School, Shounen, Slice of Life   TV       12    8.35
# 13                Drama, Historical, Seinen, Thriller   TV       26    8.64
# 14  Action, Comedy, Historical, Mystery, Seinen, S...   TV       13    8.54
# 15         Action, Drama, Sci-Fi, Seinen, Super Power   TV       26    7.97
# 16              Action, Police, Psychological, Sci-Fi   TV       22    8.50
# 17  Action, Adventure, Comedy, Historical, Romance...   TV       94    8.43
# 18                 Action, Adventure, Comedy, Shounen   TV      103    8.20
# 19              Game, Psychological, Seinen, Thriller   TV       26    8.02
#
#     members  mean rating
# 0    283069     1.221625
# 1    715151     1.059099
# 2    600384     0.953255
# 3    195017     0.879045
# 4    896229     0.801306
# 5    166255     0.769938
# 6    157670     0.757421
# 7    194611     0.731873
# 8    268487     0.716518
# 9    623511     0.695365
# 10   440334     0.680645
# 11   148328     0.654879
# 12   258914     0.654135
# 13   139474     0.638780
# 14   363215     0.616071
# 15    95825     0.599836
# 16   509109     0.544169
# 17   218928     0.544169
# 18   334399     0.538182
# 19    48127     0.538182
